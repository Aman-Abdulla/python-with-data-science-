# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Import the data from other csv file to here for processing 
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df[['Name','Survived']]
# Out:
#                                              Name  Survived
# 0                                Kelly, Mr. James         0
# 1                Wilkes, Mrs. James (Ellen Needs)         1
# 2                       Myles, Mr. Thomas Francis         0
# 3                                Wirz, Mr. Albert         0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1
# ..                                            ...       ...
# 413                            Spector, Mr. Woolf         0
# 414                  Oliva y Ocana, Dona. Fermina         1
# 415                  Saether, Mr. Simon Sivertsen         0
# 416                           Ware, Mr. Frederick         0
# 417                      Peter, Master. Michael J         0
#
# [418 rows x 2 columns]

# %%
df.iloc[:100]  #Access first 100 records
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 95          987         0       3
# 96          988         1       1
# 97          989         0       3
# 98          990         1       3
# 99          991         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                                ...     ...   ...    ...
# ...

# %%
#After loading the data first few steps:
#1. data.info()
#2. data.describe()
#3. data.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()    # Finds all Statistical values of int and float columns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.head(3)    #fetch first n values    Can go max to 30
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %%
df.tail(3)     #Fetch last n values     can go max 30
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
#      SibSp  Parch              Ticket     Fare Cabin Embarked
# 415      0      0  SOTON/O.Q. 3101262   7.2500   NaN        S
# 416      0      0              359309   8.0500   NaN        S
# 417      1      1                2668  22.3583   NaN        C

# %%
#Analyzing single column   univariate analysis
df.Survived.value_counts()      #Counts number of unique values in the column
# Out:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
df.Survived.value_counts().plot(kind='pie', autopct= '%.1f%%')   #autopct is auto percentage for each column and  format will be '%.xf%%'
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
df.Pclass.value_counts().plot(kind='pie', autopct='%.1f%%')      #Autopct only used in pie
# Out:
# <AxesSubplot:ylabel='Pclass'>

# %%
df.Sex.value_counts()    #Value_count can count any type of column
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
df.Name.nunique()      #Counts number of unique values
# Out:
# 418

# %%
df.Embarked.unique()    #Counts unique values
# Out:
# array(['Q', 'S', 'C'], dtype=object)

# %%
df.Fare.max()
# Out:
# 512.3292

# %%
df.Fare.plot(figsize=(20,5), kind = 'area')  #Figsize used to alter chart and kind is another attribute
# Out:
# <AxesSubplot:>

# %%
#Pivot table
df.pivot_table(index='Pclass', values = 'Fare', aggfunc = 'sum').plot(kind='pie', autopct='%.1f%%', subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Fare'>], dtype=object)
